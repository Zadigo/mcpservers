# %%
import pandas
import json

# %%
df = pandas.read_parquet("media/elus-conseiller-darrondissement-ca.parquet")

# %%
df.head(2)
# Out:
#    code_du_departement libelle_du_departement  code_de_la_commune  \
# 0                   13       Bouches-Du-Rhône               13055
# 1                   13       Bouches-Du-Rhône               13055
#
#   libelle_de_la_commune   libelle_du_secteur nom_de_lelu prenom_de_lelu  \
# 0             Marseille  Marseille Secteur 1       AMICO        Patrick
# 1             Marseille  Marseille Secteur 1    BOURNEUF       Aurelien
#
#   code_sexe date_de_naissance  code_de_la_categorie_socio_professionnelle  \
# 0         M        1955-08-25                                          74
# 1         M        2000-04-18                                          56
#
#      libelle_de_la_categorie_socio_professionnelle date_de_debut_du_mandat  \
# 0                                     Ancien cadre              2026-03-22
# 1  Personnel des services directs aux particuliers              2026-04-05
#
#   libelle_de_la_fonction date_de_debut_de_la_fonction
# ...

# %%
df['libelle_de_la_categorie_socio_professionnelle'].groupby(df['libelle_de_la_categorie_socio_professionnelle']).count().to_json()
# Out:
# '{"Ancien artisan, commer\\u00e7ant, chef d\'entreprise":16,"Ancien cadre":56,"Ancien employ\\u00e9":14,"Ancien ouvrier":2,"Ancienne profession interm\\u00e9diaire":8,"Artisan":11,"Cadre administratif et commercial d\'entreprise":185,"Cadre de la fonction publique":167,"Chef d\'entreprise de 10 salari\\u00e9s ou plus":19,"Commer\\u00e7ant et assimil\\u00e9":35,"Contrema\\u00eetre, agent de ma\\u00eetrise":6,"El\\u00e8ve, \\u00e9tudiant":45,"Employ\\u00e9 administratif d\'entreprise":20,"Employ\\u00e9 civil et agent de service de la fonction publique":28,"Employ\\u00e9 de commerce":11,"Ing\\u00e9nieur et cadre technique d\'entreprise":61,"Ouvrier agricole":1,"Ouvrier qualifi\\u00e9 de la manutention, du magasinage et du transport":1,"Ouvrier qualifi\\u00e9 de type artisanal":2,"Ouvrier qualifi\\u00e9 de type industriel":1,"Personne diverse sans activit\\u00e9 professionnelle de 60 ans et plus (sauf retrait\\u00e9)":7,"Personne diverse sans activit\\u00e9 professionnelle de moins de 60
# ...
